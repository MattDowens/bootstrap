# %%
import bootstrap
from ising_gap_class import IsingGap
import matplotlib.pyplot as plt
import time
import datetime
import numpy as np

# %% [markdown]
# We iterate through values of mmax with other parameters at fixed values.
# {'dim': 3, 'kmax': 7, 'lmax': 7, 'nmax': 4, 'mmax': }.
#
# N.B. The set default for 'lmax' is 7, so we change this in inputs attribute of the class before running iterate_parameter.
#
# For comparison, here is the relevant figure from the paper:
#
#
# <img src="ising_gap.png" alt="Drawing" style="width: 500px;"/>

# %%
sig_set=np.arange(0.5,0.85,0.05)
eps_set=np.arange(1.0,2.2,0.2)
ising_gap=IsingGap(3.0, sig_set, eps_set)
mmax_range=np.arange(2,10,1)
ising_gap.iterate_parameter('mmax', mmax_range)
# Out:
# /Users/MatthewDowens/Dropbox/PhD/bootstrap/pycftboot/bootstrap.py:952: RuntimeWarning: invalid value encountered in subtract
#   product *= x - (p - shift)
# /Users/MatthewDowens/Dropbox/PhD/bootstrap/pycftboot/bootstrap.py:953: RuntimeWarning: invalid value encountered in add
#   return (base ** (x + shift)) / product
# ------------------------------------------------------
# KeyboardInterrupt    Traceback (most recent call last)
# <ipython-input-2-351eb3cde980> in <module>()
#       3 ising_gap=IsingGap(3.0, sig_set, eps_set)
#       4 mmax_range=np.arange(2,10,1)
# ----> 5 ising_gap.iterate_parameter('mmax', mmax_range)
#
# ~/Dropbox/PhD/bootstrap/pycftboot/ising_gap_class.py in iterate_parameter(self, par, par_range)
#      54             tab1=bootstrap.ConformalBlockTable(self.inputs['dim'],self.inputs['kmax'],self.inputs['lmax'],self.inputs['mmax'],self.inputs['nmax'])
#      55             tab2=bootstrap.ConvolvedBlockTable(tab1)
# ---> 56             self.plot_grid(par,x,tab2)
#      57         end_time=time.time()
#      58         end_cpu=time.clock()
#
# ~/Dropbox/PhD/bootstrap/pycftboot/ising_gap_class.py in plot_grid(self, par_name, par_value, table)
#      28                 sdp.set_bound(0,float(self.gap))
#      29                 sdp.add_point(0,eps)
# ---> 30                 result=sdp.iterate()
#      31                 if result:
#      32                     allowed_sig.append(sig)
#
# ~/Dropbox/PhD/bootstrap/pycftboot/bootstrap.py in iterate(self, name)
#    1207         """
#    1208         obj = [0.0] * len(self.table[0][0][0].vector)
# -> 1209         self.write_xml(obj, self.unit, name)
#    1210
#    1211         os.spawnvp(os.P_WAIT, sdpb_path, ["sdpb", "-s", name + ".xml", "--precision=" + str(prec), "--findPrimalFeasible", "--findDualFeasible", "--noFinalCheckpoint"] + self.options)
#
# ~/Dropbox/PhD/bootstrap/pycftboot/bootstrap.py in write_xml(self, obj, norm, name)
#    1101
#    1102                     for n in range(0, len(polynomial_vector)):
# -> 1103                         expression = polynomial_vector[n].expand()
#    1104                         # Impose unitarity bounds and the specified gap
#    1105                         expression = expression.subs(delta, delta + delta_min).expand()
#
# KeyboardInterrupt:
